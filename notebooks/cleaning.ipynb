# %%
# load data from the sgdb.db which is a sqlite db into a data frame
import pandas as pd
import sqlite3
import os
import sys

# adds parent directory to sys.path
from pathlib import Path
import json
sys.path.append(str(Path(os.getcwd()).resolve().parent))  # Add the parent directory to the path

from src.preprocess.names import NameProcessor

# %%
data_dir = '/Users/syamil/Projects/searchgov/data'
names_parquet = os.path.join(data_dir, 'names.parquet')
FORCE_RELOAD = True
if not os.path.exists(names_parquet) or FORCE_RELOAD:
    # Load the names from the sqlite database and save them to a parquet file
    conn = sqlite3.connect(os.path.join(data_dir, 'sgdb.db'))
    df = pd.read_sql_query("SELECT * FROM names", conn)
    df.to_parquet(names_parquet, index=False)
else:
    # Load the names from the parquet file
    df = pd.read_parquet(names_parquet)

# %%
processor = NameProcessor()

res = processor.process_names(df, 'name')
# Out:
# 2025-06-15 17:36:07.155 | INFO     | src.preprocess.names:process_names:206 - Processing 6214472 names in column 'name'.

# %%
from html import unescape
res['org'] = res['org'].map(lambda x: unescape(x) if isinstance(x, str) else x)

# %%
# only get orgs and url for pre seeding

orgs = res[['org', 'url','date_created']]
# do

# .sort_values(by='date_created', ascending=True).drop_duplicates(subset=['org','url'], keep='first').reset_index(drop=True)

# %%
from urllib.parse import urlparse
from collections import deque
import re
def get_sgdi_entity_type(url):
    path = urlparse(url).path.strip('/')
    parts = path.split('/')

    if len(parts) >= 2 and parts[0].lower() == 'ministries':
        if len(parts) == 2:
            return 'ministry'
        elif len(parts) >= 4:
            if parts[-2].lower() == 'statutory-boards':
                return 'statutory board'
            elif parts[-2].lower() == 'departments':
                return 'department'
            elif parts[-2].lower() == 'others':
                return 'others'
            elif parts[-2].lower() == 'committees':
                return 'committee'
    return 'unknown'

def get_parent_url(url):
    parts = url.split('/')
    if len(parts) > 3:
        return '/'.join(parts[:-2])  # Return the URL up to the parent level
    return None

def get_sub_parent_org(string:str):
        
    pattern = re.compile(r'https://www.sgdi.gov.sg/ministries/([^/]+)/(statutory-boards|departments|committees|others)/([^/]+)')
    
    match = pattern.match(string)
    
    if match:
        parent_department_url = string.rsplit('/', 2)[0] 
        return parent_department_url
    else:
        return None
    
def get_org_parts(url: str):
    """
    Generically extracts organizational parts from an SGDI URL.

    It works by identifying a set of "marker" words and extracting the
    URL path segment that immediately follows each marker.
    """
    # Define the words that signal that the *next* segment is important.
    # Using a set for fast lookups.
    MARKER_WORDS = {
        "ministries",
        "statutory-boards",
        "departments",
        "committees",
        "others",
    }

    try:
        # 1. Safely parse the URL into its components.
        parsed_url = urlparse(url)
        # 2. Get the path and split it into a clean list of segments.
        # .strip('/') removes potential empty strings at the start or end.
        segments = parsed_url.path.strip("/").split("/")
    except Exception:
        # Handle cases where the input is not a valid URL
        return None

    extracted_parts = []
    # 3. Iterate through the segments to find our data.
    for i, segment in enumerate(segments):
        # Check if the current segment is one of our markers
        if segment in MARKER_WORDS:
            # Ensure there is a next segment to grab
            if i + 1 < len(segments):
                value = segments[i + 1]
                # We also check that the value itself isn't another marker
                if value not in MARKER_WORDS:
                    extracted_parts.append(value)

    return tuple(extracted_parts)
    
def create_org_summary(df):
    """
    Create start_date and end_date for each org
    """
    # create a copy
    df_copy = df.copy()
    df_copy['date_created'] = pd.to_datetime(df_copy['date_created'])
    
    # Group by person, position, and organization
    org_duration = df_copy.groupby(['url','org']).agg({
        'date_created': ['min', 'max'],  # Get min and max for each group
        'url': 'first',  # Get the first URL for each group
    }).reset_index()
    
    # Flatten column names
    org_duration.columns = ['url', 'org', 'start_date', 'end_date', 'first_url']
    
    # rename columns
    org_duration.rename(columns={
        'start_date': 'first_observed',
        'end_date': 'last_observed',
    }, inplace=True)

    return org_duration

def get_parent_url_robust(url):
    """
    A robust function to get the parent URL.
    Returns None if it's a top-level ministry.
    """
    # A ministry URL (e.g., .../ministries/MOF) doesn't have a parent in this context.
    if get_sgdi_entity_type(url) == "ministry":
        return None
    # For all others, the parent is the URL minus the last two path segments.
    if "/" in url:
        return url.rsplit("/", 2)[0]
    return None
def build_complete_org_hierarchy(raw_orgs_df):
    """
    Builds a complete hierarchy, creating missing parents, inferring names
    and dates, and standardizing all org names to a 'PARENT : CHILD' format.
    """
    print("1. Summarizing initial organization data...")
    df = create_org_summary(raw_orgs_df)
    # Add a flag to distinguish original orgs from inferred ones
    df["is_inferred"] = False

    print("2. Pass 1: Discovering missing parents and creating placeholders...")
    initial_map_df = df.drop_duplicates(subset="url", keep="last")
    url_to_org_name_map = initial_map_df.set_index("url")["org"]

    existing_urls = set(df["url"])
    urls_to_check = deque(df["url"])
    new_rows = []

    while urls_to_check:
        current_url = urls_to_check.popleft()
        parent_url = get_parent_url_robust(current_url)

        if parent_url and parent_url not in existing_urls:
            print(f"   - Found missing parent: {parent_url}")
            existing_urls.add(parent_url)
            urls_to_check.append(parent_url)

            # Infer the clean name without any prefixes
            inferred_name = "Unknown"
            child_name = url_to_org_name_map.get(current_url)
            if child_name and ":" in child_name:
                inferred_name = child_name.split(":", 1)[0].strip()
            else:
                parts = get_org_parts(parent_url)
                if parts:
                    inferred_name = parts[-1].upper() # Just the part, e.g., 'CD'

            new_row = {
                "url": parent_url,
                "org": inferred_name,
                "first_observed": pd.NaT,
                "last_observed": pd.NaT,
                "first_url": parent_url,
                "is_inferred": True, # Flag this row as machine-generated
            }
            new_rows.append(new_row)

    if new_rows:
        new_orgs_df = pd.DataFrame(new_rows)
        combined_df = pd.concat([df, new_orgs_df], ignore_index=True)
        print(f"\n   -> Added {len(new_rows)} new organization(s).")
    else:
        combined_df = df

    print("3. Pass 2: Recursively aggregating dates for new parents...")
    combined_df["sub_parent_org_url"] = combined_df["url"].apply(
        get_parent_url_robust
    )
    new_parent_urls = {row["url"] for row in new_rows}
    sorted_new_parent_urls = sorted(
        list(new_parent_urls), key=len, reverse=True
    )

    for parent_url in sorted_new_parent_urls:
        children_df = combined_df[
            combined_df["sub_parent_org_url"] == parent_url
        ]
        if not children_df.empty:
            min_date = children_df["first_observed"].min(skipna=False)
            max_date = children_df["last_observed"].max(skipna=False)
            parent_index = combined_df.index[combined_df["url"] == parent_url]
            combined_df.loc[parent_index, "first_observed"] = min_date
            combined_df.loc[parent_index, "last_observed"] = max_date

    print("4. Pass 3: Finalizing links and reconstructing all names...")
    # First, get the initial parent names
    unique_orgs_for_mapping = combined_df.drop_duplicates(
        subset="url", keep="last"
    )
    url_to_name_map = unique_orgs_for_mapping.set_index("url")["org"]
    combined_df["sub_parent_org_name"] = combined_df[
        "sub_parent_org_url"
    ].map(url_to_name_map)

    # --- NAME AND TYPE RECONSTRUCTION ---
    def get_base_name(org_name):
        """Extracts the 'child' part of a name."""
        if pd.isna(org_name):
            return "Unknown"
        return org_name.split(":", 1)[-1].strip()

    # Get the base name for every org before we overwrite them
    combined_df["base_name"] = combined_df["org"].apply(get_base_name)

    # Rebuild the final org name for consistency
    combined_df["org"] = combined_df.apply(
        lambda row: f"{row['sub_parent_org_name']} : {row['base_name']}"
        if pd.notna(row["sub_parent_org_name"])
        else row["org"], # Keep original name for ministries
        axis=1,
    )

    # Now, set the final entity type for inferred orgs
    combined_df["sgdi_entity_type"] = combined_df["url"].apply(
        get_sgdi_entity_type
    )
    combined_df.loc[
        combined_df["is_inferred"] == True, "sgdi_entity_type"
    ] = "inferred"

    # Clean up temporary columns
    combined_df = combined_df.drop(columns=["is_inferred", "base_name"])
    # --- END RECONSTRUCTION ---

    combined_df["parts"] = combined_df["url"].apply(get_org_parts)
    combined_df = combined_df.sort_values(by="url").reset_index(drop=True)

    print("5. Hierarchy construction complete.")
    return combined_df
transformed_org = build_complete_org_hierarchy(orgs)
    
# transformed_org['sub_parent_org_url'] = transformed_org.url.map(lambda x : get_sub_parent_org(x))
# transformed_org['parts'] = transformed_org.url.map(lambda x : get_org_parts(x))
# orgs['parent_org_url'] = orgs.url.map(lambda x : re.match(r'https://www.sgdi.gov.sg/ministries/([^/]+)', x).group(0) if re.match(r'https://www.sgdi.gov.sg/ministries/([^/]+)', x) else None)
# transformed_org['sgdi_entity_type'] = transformed_org['url'].map(get_sgdi_entity_type)
# Out:
# 1. Summarizing initial organization data...
# 2. Pass 1: Discovering missing parents and creating placeholders...
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/CD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/CD/departments/fmp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/agd/departments/ft/departments/building-cumulus-community
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/agd/departments/ft
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/agd/departments/ft/departments/projects-2
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/agd/departments/po/departments/fcd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/agd/departments/po/departments/po
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/agd/departments/ro
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/ced
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/cp2m
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/efa
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/ep
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/fp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/fsp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/gpfo
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/id
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/ld
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/lip
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/pe
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/ri
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/sc/departments/cd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/sc/departments/compliance
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/sc/departments/hr-dir
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/sc/departments/ii
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/sc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/sc/departments/itd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/sc/departments/otm
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/sc/departments/pp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/sc/departments/trade
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/sp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/srp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/tax
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/vital/departments/cd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/vital/departments/cs
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/vital/departments/fas
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/vital/departments/fs
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/vital/departments/hpa
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/vital/departments/hpe
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/vital/departments/hps
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/vital/departments/sic
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/bizgrp/departments/csid
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/bizgrp/departments/ctd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/bizgrp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/bizgrp/departments/tpr
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/bizgrp/departments/tptd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/casegrp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/casegrp/departments/iitd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/casegrp/departments/txd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/corpsvcgrp/departments/cdd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/corpsvcgrp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/corpsvcgrp/departments/enfd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/corpsvcgrp/departments/infod
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/corpsvcgrp/departments/law
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/corpsvcgrp/departments/rcsd-1
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/iiitgrp/departments/gstd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/iiitgrp/departments/ifd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/iiitgrp/departments/itard
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/iiitgrp/departments/ptd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/indivgrp/departments/iitd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/indivgrp/departments/tpsd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/tote-board/departments/strategic-planning-amp-finance-divisiontoteboard
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/tote-board/departments/tote-board-1
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/tote-board/departments/tote-board-2
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/tote-board/departments/tote-board-3
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/tote-board/departments/tote-board-6
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/tote-board/departments/tote-board
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/departments/nyc/departments/ye--c
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/departments/nyc/departments/ye--c/departments/yl-ia--aep
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/departments/nyc/departments/ye/departments/yl-ia--aep
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/muis/departments/mcm
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/muis/departments/oom
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/SD/departments/ed
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/SD/departments/la
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/SD/departments/pa
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/SD/departments/va
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/aeg/departments/emd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/ipg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/ipg/Departments/scm
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/ipg/Departments/spe
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/p--cd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/p--cd/Departments/ep
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/p--cd/Departments/finance
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/p--cd/Departments/hr--admin
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/p--cd/Departments/hr--admin/departments/hr
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/p--cd/Departments/m-c--ds
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/p--cd/Departments/pp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/pampc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nhb/departments/HROD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nhb/departments/hrod
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/pa/departments/grassroots/departments/residents-network
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/pa/departments/other
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/departments/csa/departments/cp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/departments/dso
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/departments/erd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/departments/ind
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/departments/spd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cce
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cce/departments/gl
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cdw/departments/mpc/departments/cs
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cdw/departments/mpc/departments/sp--oc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cdw/departments/mpc/departments/sp--oc/departments/pofma
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cdw/departments/mpc/departments/spampo
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cdw/departments/mpc/departments/spampo/departments/pofma
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cdw/departments/prcd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cdw/departments/prcd/departments/smpo/departments/poma-office
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cdw/departments/rcig
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cg/departments/hr
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cg/departments/img
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cg/departments/img/departments/pc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cg/departments/itd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/cg/departments/wod
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/corp/departments/itd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/ig
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/spdr/departments/spc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/spdrg/departments/drc/departments/drcc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/imda/departments/stg/departments/dtc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/alg/departments/pd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/cg/departments/fpa
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg/departments/de
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg/departments/nas
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg/departments/nl
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg/departments/pd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg/departments/pl-1
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg/departments/pl/departments/cr
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg/departments/pl/departments/er
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg/departments/pl/departments/nr
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg/departments/pl
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg/departments/pl/departments/wr
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg/departments/px
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/ccd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/cg/departments/fpa
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/cg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/cg/departments/pfm
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/cg/departments/rdm
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/pmd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/psg/departments/pd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/psg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/psg/departments/str
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/tsg/departments/dss
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/tsg/departments/ias
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/tsg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/tsg/departments/tpg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/tsg/departments/csi
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/tsg/departments/dss
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/tsg/departments/ias
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/tsg/departments/tmo
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/tsg/departments/tpg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mddi/departments/sndg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mddi/departments/spd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mddi/statutory-boards/imda/departments/cdw/departments/c2r/departments/rc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mddi/statutory-boards/nlb/departments/tsg/departments/csi
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mddi/statutory-boards/nlb/departments/tsg/departments/tmo
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/cad/departments/ga/departments/(os)/departments/(evs)
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/cad/departments/ga/departments/(os)/departments/evs
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/cad/departments/proc-fa/departments/(proc)
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/cad/departments/procfa
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/cad/departments/procfa/departments/(proc)
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/con/departments/co
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/con/departments/cp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/con/departments/cp/departments/ep
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/con
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/da/departments/tp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/hrd/departments/hrd/departments/cd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/hrd/departments/hrd/departments/mppr
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/hrd/departments/hrd/departments/pm
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/hrd/departments/hrd/departments/trg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/hrd/departments/hrm/departments/ras
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/imd/departments/is/departments/rec
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/hq/departments/pro/departments/vf
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/om/departments/cg-hcg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/om/departments/cghcg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/om/departments/con-hcs
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/om/departments/conhcs
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/om/departments/emb
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/om/departments/hc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/om/departments/io
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/CCSD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/arpt
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/coastal
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/enf
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/ica-trg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/icasc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/icc-air
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/icc-land
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/icc-sea
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/imd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/intel-div
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/lif-div
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/mp-div
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/ops-div
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/pdd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/ports
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ICA/departments/prd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/finance--and-admin-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/finance--and-admin-division/departments/admin
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/ica/departments/icasc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/jog/departments/JOM
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/planning--and-organisation-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/scdf/departments/hqscdf
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/spf/departments/cad/departments/fig/departments/tfd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/sps
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/sps/departments/lfd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/sps/departments/ttd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/departments/technology-and--logistics-policy-division-tlpd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/CRA/departments/cdd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/CRA/departments/ict
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/CRA/departments/ld
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/CRA/departments/pcd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/YRSG/departments/CDG
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/YRSG/departments/rg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/cbrne/departments/border-operations--specialised-lab
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/cbrne/departments/operations
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/cbrne/departments/technology-development
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/cybersecurity/departments/cybersecurity-ops--resiliency
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/cybersecurity/departments/cybersecurity-resiliency-ops-system
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/cybersecurity/departments/design-amp-assessment
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/cybersecurity/departments/planning-amp-governance
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/cybersecurity/departments/technology-development
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/data-science--ai/departments/cognitive-computing
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/data-science--ai/departments/decision-science
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/forensics/departments/capability-development
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/land-systems/departments/armament-systems-engineering
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/land-systems/departments/vehicle-systems-engineering
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/land-systems/departments/vehicle-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/land-systems/departments/weapons-amp-armament-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/protective-security--safety/departments/consultation-amp-fire-safety-engineering--branch-opcon-scdf
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/protective-security--safety/departments/consultations-amp-solutions
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/protective-security--safety/departments/protective-engineering-division-opcon-spf
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/protective-security--safety/departments/research-amp-development
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/robotics-automation--unmanned-systems/departments/3i
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/sense-making-and-surveillance-coe/departments/ai-engineering
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/sense-making-and-surveillance-coe/departments/ai-rd-(vision-ai)
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/sense-making-and-surveillance-coe/departments/systems-solutioning
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/sensemaking--surveillance/departments/engineering
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/sensemaking--surveillance/departments/masterplanning-amp-capdev
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/coe/departments/sensemaking--surveillance/departments/tech-masterplanning--reporting
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/enterprise-group/departments/htxai-enablers
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/enterprise-group/departments/xcdi/departments/mobile-core-amp-transmission
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/enterprise-group/departments/xcdi/departments/wireless-access--sensor-deployment
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/enterprise-group/departments/xcloud/departments/collaboration-system
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/enterprise-group/departments/xdata/departments/cognitive-computing
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/enterprise-group/departments/xdata/departments/decision-science
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/corrections--narcotics/departments/corrections
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/corrections--narcotics/departments/narcotics
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/immigration--checkpoints/departments/automation-amp-analytics
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/immigration--checkpoints/departments/border-protection
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/immigration--checkpoints/departments/identity-management
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/immigration--checkpoints/departments/infrastructure-amp-security
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/immigration--checkpoints/departments/people-clearance
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/intel/departments/programmes-amp-solutions
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/joint-capabilities/departments/cloud-transformation
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/joint-capabilities/departments/communications
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/joint-capabilities/departments/cyber-tech-stack
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/joint-capabilities/departments/data-ops-management-amp-analytics
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/joint-capabilities/departments/enterprise-digital-infrastructure
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/joint-capabilities/departments/enterprise-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/joint-capabilities/departments/ops-infra
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/policing/departments/hse-office
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/policing/departments/investigation-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/policing/departments/operations-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/policing/departments/operations-systems/departments/infocomm
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/policing/departments/training--learning-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmc/departments/policing/departments/training-amp-learning-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/intel/departments/development
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/mhq--training-pmc/departments/training-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/pmg-nexus/departments/standards--architecture-office
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/policing/departments/training-learning-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/cdpmc/departments/c2-ops-support-amp-frontline-mobility-system
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/cdpmc/departments/cbrne-amp-early-warning
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/cnpmc/departments/corrections
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/cnpmc/departments/narcotics
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/icpmc/departments/automation-amp-analytics
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/icpmc/departments/border-protection
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/icpmc/departments/clearance
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/icpmc/departments/identity-management
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/icpmc/departments/infrastructure-amp-security
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/icpmc/departments/people-clearance
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/intel-pmc/departments/intelligence-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/intel-pmc/departments/intelligence-technology
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/intel-pmc/departments/programmes-amp-solutions
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/ppmc/departments/investigation-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/ppmc/departments/operations-systems-(engineering)
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-development/departments/pmg/departments/programme-centres/departments/ppmc/departments/operations-systems-(infocomm)
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-planning
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-planning/departments/corp--finance/departments/corporate-services
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-planning/departments/corp--finance/departments/htx-workplace-transformation
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-planning/departments/corp-finance/departments/htx-workplace-transformation
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-planning/departments/cpo/departments/collaboration-amp-agile
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-planning/departments/cpo/departments/ict-amp-building-amp-infra
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-planning/departments/cpo/departments/platforms-amp-services
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-planning/departments/cpo/departments/policy-amp-plans
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-planning/departments/hr/departments/leadership-and-development
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-sustainment/departments/ict-infra/departments/capability-sustainment
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-sustainment/departments/ict-infra/departments/capability-sustainment/departments/policing-ict-infra
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-sustainment/departments/ict-infra/departments/civil-defence-cap-sus
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-sustainment/departments/ict-infra/departments/corrections-cap-sus
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-sustainment/departments/ict-infra/departments/immigration--checkpoint-cap-sus
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-sustainment/departments/ops-systems/departments/cybersecurity-resiliency
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-sustainment/departments/ops-systems/departments/governance-amp-control
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-sustainment/departments/ops-systems/departments/policing-cap-sustainment
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/capability-sustainment/departments/platforms-systems
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/csc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/csc/departments/ict-infra/departments/capability-sustainment
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/csc/departments/ict-infra/departments/capability-sustainment/departments/policing-ict-infra
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/htx/departments/csc/departments/ict-infra/departments/joint-ict-infra
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/yrsg/departments/cdg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mha/statutory-boards/yrsg/departments/rg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mindef/departments/dmg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mindef/departments/dpg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mindef/departments/m-smc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mindef/departments/msmc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mindef/departments/sf
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mindef/departments/smcc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mindef/departments/ts
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mindef/statutory-boards/dsta/departments/cd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mindef/statutory-boards/dsta/departments/pc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/committees/la
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/committees/la/departments/sal/departments/cdss/departments/cs
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/committees/la/departments/sal/departments/cdss/departments/ss
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/ab
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/abla
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/clsg/departments/acd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/clsg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/clsg/departments/lab
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/clsg/departments/oapt
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/clsg/departments/oapt/departments/io/departments/cid
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/clsg/departments/oapt/departments/io/departments/iidrsd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/clsg/departments/oapt/departments/lapd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/clsg/departments/oapt/departments/led
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/clsg/departments/oapt/departments/lripd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/community-legal-services-group/departments/anti-money-laundering--countering-the-financing-of-terrorism-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/community-legal-services-group
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/community-legal-services-group/departments/insolvency--public-trustees-office/departments/insolvency-office
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/community-legal-services-group/departments/insolvency--public-trustees-office/departments/insolvency-office/departments/individual-insolvency--debt-repayment-scheme-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/community-legal-services-group/departments/insolvency--public-trustees-office/departments/legal-advisory--prosecution-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/community-legal-services-group/departments/insolvency--public-trustees-office/departments/licensing--enforcement-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/community-legal-services-group/departments/insolvency--public-trustees-office/departments/licensing--regulation-of-insolvency-practitioners-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/community-legal-services-group/departments/insolvency--public-trustees-office/departments/public-trustees-office
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/community-legal-services-group/departments/insolvency-public-trustee's-office/departments/insolvency-office
# ...
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/stb/departments/PPG/departments/tatg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/stb/departments/TTG
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/stb/departments/TTG/departments/col
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/stb/departments/TTG/departments/ve-1
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/nscs/departments/strat-plng--prog
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/psd/departments/CHRG
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/psd/departments/CHRG/Departments/hrp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/psd/departments/WD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/psd/departments/cg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/psd/departments/cg/departments/it/departments/psd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/psd/departments/cg/departments/pcg/departments/sc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/psd/departments/chrg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/psd/departments/lg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/psd/departments/pstg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/sg/departments/cd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/sg/departments/sppd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/departments/stppo
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/csc/departments/CCE
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/csc/departments/STO
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/csc/departments/etg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/csc/departments/igp/departments/se
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/csc/departments/scg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/govtech/departments/c
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/EPG/departments/EKM
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/EPG/departments/EKM/Departments/EAD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/EPG/departments/EKM/Departments/EKD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/EPG/departments/EKM/Departments/ESD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/EPG/departments/EKM/Departments/msd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/cdg/departments/opdg/departments/hrd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/cdg/departments/tg/departments/DTA
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/BIG/departments/bd-i
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/BIG/departments/bd-ii
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/BIG/departments/bd-iii
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/BIG/departments/id
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/BIG/departments/imd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/BIG
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/cmg/departments/CFC
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/cmg/departments/cfc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/cmg/departments/cmi-i
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/cmg/departments/cmi-ii
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/cmg/departments/cmi-iii
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/cmg/departments/mpi
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/fsg/departments/ppfg/departments/PD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/mdg/departments/dig/departments/FMD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/departments/vital
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/iiitgrp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/MOF/statutory-boards/iras/departments/indivgrp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mccy/statutory-boards/nac/departments/SD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mci/statutory-boards/nlb/departments/nlb/departments/alg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mfa/departments/om
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/clsg/departments/oapt/departments/io
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/community-legal-services-group/departments/official-assignee--public-trustees-office
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/community-legal-services-group/departments/official-assignee--public-trustees-office/departments/insolvency-office
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/corporate-services-1
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/corporate-services-1/departments/finance-office-administration-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/corporate-services-divisions
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/corporate-services-divisions/departments/finance--office-administration-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/corporate-services-divisions/departments/finance-office-administration-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/corporate-services
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/csd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/csd/departments/foa
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/international--advisory-group
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/policy-divisions
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/policy-divisions/departments/strategic-planning--policy-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/minlaw/departments/policy-divisions/departments/strategic-planning-policy-division
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mnd/statutory-boards/NPARKS/departments/avs
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mnd/statutory-boards/NPARKS/departments/npgnrc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mnd/statutory-boards/NPARKS/departments/pdsc/departments/ppd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mnd/statutory-boards/bca/departments/BCAA
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/moe/departments/cpdd2/departments/ELLB
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/moe/departments/ifsd/departments/HQSB
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/moe/departments/ifsd/departments/SCD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/moe/statutory-boards/SEAB/departments/aec
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/moe/statutory-boards/ssg/departments/tmig
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/moh/departments/KTPH
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/moh/departments/NUP
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/moh/departments/shp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/moh/others/shp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/moh/statutory-boards/hsa/departments/hprg/departments/vc--ec
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mom/departments/lrwd/departments/ese/departments/ops
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/caas/departments/ad
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/caas/departments/ad/departments/at
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/caas/departments/ans/departments/atmpd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/caas/departments/ans/departments/ats
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/caas/departments/corporate/departments/cd--ep
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/caas/departments/corporate/departments/cdg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/caas/departments/corporate/departments/fin
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/caas/departments/corporate/departments/to
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/caas/departments/usg/departments/cdampep
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/caas/departments/usg/departments/cdep
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/cd/departments/qsc2/departments/qsc2-2
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/nsc/departments/nsc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/pp/departments/3-pp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/pp/departments/3pp
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/rl/departments/1rleampm
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/rl/departments/2rleampm
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/rl/departments/rlem
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/rl/departments/rlem/departments/2rlem
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/sc/departments/1-sc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/sc/departments/1sc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/sc/departments/2-sc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/sc/departments/2sampc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/sc
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/tampid--ttech--itcd/departments/rdampt
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/tampid--ttech--itcd/departments/tampid
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/tid--ttech--itcd--lo/departments/nexgen
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/tid--ttech--itcd--lo/departments/tid
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/tid--ttech--itcd/departments/nexgen
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/tid--ttech--itcd/departments/rdampt
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/tid--ttech--itcd/departments/tampid
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/tid--ttech--itcd/departments/tid
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mot/statutory-boards/lta/departments/tro/departments/RO
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mse/statutory-boards/nea/departments/csg-2
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mse/statutory-boards/nea/departments/hcg/departments/tmd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mse/statutory-boards/nea/departments/jotg/departments/tssd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mse/statutory-boards/nea/departments/wsd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/msf/departments/ffs
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/msf/departments/ss/departments/spsg
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/msf/departments/ss/departments/spsg/departments/smrd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/msf/statutory-boards/ncss/departments/co/Departments/TSRD
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/msf/statutory-boards/ncss/departments/fundraise/departments/comchest
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/departments/dos/departments/BS
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/departments/dos/departments/CS
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/astar/departments/ENT/Departments/OGA
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/astar/departments/cg/departments/ccd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/astar/departments/cg/departments/fd/departments/fss
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/ema/departments/erd
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/enterprisesg/departments/gm-2/departments/ae-sa-mea
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/enterprisesg/departments/gm-2/departments/apac
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/esg/departments/gm-2/departments/ae-sa-mea
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/esg/departments/gm-2/departments/apac
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/mti/statutory-boards/stb/departments/MG
#    - Found missing parent: https://www.sgdi.gov.sg/ministries/pmo/statutory-boards/mas/departments/EPG
#
#    -> Added 1879 new organization(s).
# 3. Pass 2: Recursively aggregating dates for new parents...
# 4. Pass 3: Finalizing links and reconstructing all names...
# 5. Hierarchy construction complete.

# %% [markdown]
# # Clean up names and org

# %%
# clean up html in org and rank
res['rank'] = res['rank'].map(lambda x: unescape(x) if isinstance(x, str) else x)
# apply autocorrect
res['rank'] = res['rank'].map(lambda x: str(x).replace('&', 'and') if isinstance(x, str) else x)

# %%
def create_position_tenure(df):
    """
    Create start_date and end_date for each unique position held by each person
    """
    df['date_created'] = pd.to_datetime(df['date_created'])
    
    # Group by person, position, and organization
    position_tenure = df.groupby(['lower_name', 'rank', 'org']).agg({
        'clean_name': 'first',
        'date_created': ['min', 'max'],  # Get min and max for each group
        'email': 'last',
        'tel': 'last',
        'url': 'first',
        'type': 'first',
        'raw_name': 'first'
    }).reset_index()
    
    # Flatten column names
    position_tenure.columns = [
        'lower_name', 'rank', 'org', 'clean_name',
        'start_date', 'end_date', 'email', 'tel', 'url', 'type','raw_name'
    ]
    
    # Calculate tenure duration
    position_tenure['tenure_days'] = (
        position_tenure['end_date'] - position_tenure['start_date']
    ).dt.days
    


    return position_tenure

# %%
tenure_df = create_position_tenure(res)

# %%
# save the tenure_df to a parquet file
tenure_parquet = os.path.join(data_dir, 'tenure.parquet')
# if not os.path.exists(tenure_parquet):
tenure_df.to_parquet(tenure_parquet, index=False)

# save the transformed_org to a parquet file
orgs_parquet = os.path.join(data_dir, 'orgs.parquet')
# if not os.path.exists(orgs_parquet):
transformed_org.to_parquet(orgs_parquet, index=False)
